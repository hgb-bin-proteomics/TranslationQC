# %%
from qc_bench import Judge

import logging

logger = logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO)

# %%
judge = Judge(openai=True, anthropic=False, google=False, ollama=False)
# Out:
# ERROR:qc_bench._judge:Could not get a token for OpenAI!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 judge=Judge(openai=True, anthropic=False, google=False, ollama=False)
#
# File ~\Documents\GitHub\TranslationQC\src\qc_bench\_judge.py:818, in Judge.__init__(self, openai, anthropic, google, ollama)
#     816     self.__openai = OpenAI(api_key=str(openai).strip())
#     817 elif openai is None or openai:
# --> 818     self.__openai = OpenAI(api_key=_OpenAIModel._get_openai_api_key())
#     819 # anthropic
#     820 if isinstance(anthropic, str):
#
# File ~\Documents\GitHub\TranslationQC\src\qc_bench\_judge.py:129, in _OpenAIModel._get_openai_api_key()
#     127         return str(env["OPENAI_API_KEY"]).strip()
#     128 logger.error("Could not get a token for OpenAI!")
# --> 129 raise RuntimeError("Could not get a token for OpenAI!")
# ...
